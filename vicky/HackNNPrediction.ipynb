# %%
import os
import sys
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
text_processing_scripts_path = os.path.abspath('TextProcessingScripts')
sys.path.append(text_processing_scripts_path)

scripts_path = os.path.abspath('Scripts')
sys.path.append(scripts_path)

# %%
from FeatureExtraction.VocabDict import create_vocab_dict
from FeatureExtraction.UnknownWordsProcessing import UnknownWordsProcessing
from FeatureExtraction.Word2VecUtilities import create_word2vector_model, create_embeddings_matrix, save_word2vector_model, load_word2vector_model
from TensorflowInputProcessing.SentenceProcessing import SentenceProcessing
from TensorflowInputProcessing.DocumentProcessing import DocumentProcessing
from TensorflowInputProcessing.MapWordToID  import MapWordToID 
from CommonUtilities.FileUtilities import return_file_content, save_pickle_file, load_pickle_file

# %%
from CustomNN import create_RNN, create_attention
from CustomRNN import CustomRNN
from LengthEstimation import estimate_sentences_and_document_lengths

# %%
data_path = os.path.abspath('data_copy')
train_data = pd.read_csv(os.path.join(data_path, 'train.csv'))
test_data = pd.read_csv(os.path.join(data_path, 'test.csv'))

# %%
# test_data_copy = pd.DataFrame([test_data['company1'],test_data['company2'], test_data['is_parent'],test_data['snippet']]).T
# test_data_copy.columns = ['company2','company1','is_parent','snippet']
# test_data = pd.concat([test_data,test_data_copy])

# %%
def preprocess_and_group_data(data):
    data = data.drop_duplicates()
    data.index = range(len(data))
    aliased_snippet = []
    for i in range(len(data)):
        aliased_snippet.append(data['snippet'][i].replace(data['company2'][i],' company2 ').replace(data['company1'][i],' company1 '))
    data['snippet'] = aliased_snippet

    data['snippet'] = data['snippet'].str.lower()

    grouped_data = data.groupby(['company1','company2'])['snippet'].apply(list)
    grouped_data = grouped_data.to_frame().reset_index()
    return data, grouped_data

def word_tokenizer(string):
    return string.split()

# %%
test_data, grouped_test_data = preprocess_and_group_data(test_data)

# %%
training_params = load_pickle_file(os.path.join(data_path, 'training_params.p'))

# %%
vocab_dict = training_params['vocab_dict'] 
rev_vocab_dict = training_params['rev_vocab_dict']
estimated_sent_len = training_params['estimated_sent_len']
estimated_doc_len = training_params['estimated_doc_len']
embedding_matrix = training_params['embedding_matrix']

# %%
sentence_processing = SentenceProcessing()
document_processing = DocumentProcessing()
map_word_to_id = MapWordToID(vocab_dict)
unknown_words_processing = UnknownWordsProcessing(vocab_list=vocab_dict.keys(), replace=False)

# %%
def return_X(grouped_snippets):
    tokenized_sentences_tokenized_words = [word_tokenizer(sent) for sent in grouped_snippets]
    tokenized_sentences_tokenized_words = unknown_words_processing.remove_or_replace_unkown_word_from_sentences(tokenized_sentences_tokenized_words)
    preprocessed_sentences_of_document = sentence_processing.pad_truncate_sent(tokenized_sentences_tokenized_words, estimated_sent_len,  dummy_token='my_dummy')
    preprocessed_document = document_processing.pad_truncate_document(preprocessed_sentences_of_document, estimated_doc_len, estimated_sent_len)
    id_array = np.asarray(map_word_to_id.word_lists_to_id_lists(preprocessed_document))
    return id_array

# %%
X_test = []
y_test = []
for index , row in grouped_test_data.iterrows():
    grouped_snippets = row['snippet']
    id_array = return_X(grouped_snippets)
    X_test.append(id_array)
    y_test.append(0)

# %%
import tensorflow as tf
from tensorflow.contrib.layers import fully_connected

# %%
tf.reset_default_graph()

# %%
sess = tf.Session()
saver = tf.train.import_meta_graph(os.path.join(data_path,"consent.ckpt.meta"))
saver.restore(sess, os.path.join(data_path,"consent.ckpt"))
graph = tf.get_default_graph()

X = graph.get_operation_by_name('Inputs/X').outputs[0]
y = graph.get_operation_by_name('Inputs/y').outputs[0]
tf_keep_prob = graph.get_operation_by_name('Inputs/tf_keep_prob').outputs[0]
tf_sentences_length = graph.get_operation_by_name('Inputs/sentences_length').outputs[0]
tf_documents_length = graph.get_operation_by_name('Inputs/documents_length').outputs[0]
normalized_sentence_attentions = graph.get_operation_by_name('Attention-2/ExpandDims').outputs[0]
prob = graph.get_operation_by_name('Prediction/prob').outputs[0]
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from /home/radoslav/git/team_a/vicky/data_copy/consent.ckpt

# %%
# validation_data = load_pickle_file(os.path.join(data_path, 'validation_data.p'))
# X_valid = validation_data['X_valid']
# y_valid = validation_data['y_valid']

# %%
X_valid_samples, y_valid_samples = np.asarray(X_test), np.asarray(y_test).reshape(len(y_test),1)
valid_sentences_length, valid_documents_length = estimate_sentences_and_document_lengths(X_valid_samples, vocab_dict['my_dummy'])

# %%
np_normalized_sentence_attentions, np_prob, np_y = sess.run([normalized_sentence_attentions, prob, y],
                                                            feed_dict={X:X_valid_samples, y:y_valid_samples,tf_sentences_length:valid_sentences_length, tf_documents_length:valid_documents_length,tf_keep_prob:1})
attention_scores = np.squeeze(np_normalized_sentence_attentions)

# %%
np_y = y_valid_samples
accuracy = sum((np_prob>0.5)==(np_y>0.5))/len(np_y)
accuracy
# Out:
# array([0.90377113])

# %%
_, grouped_test_data = preprocess_and_group_data(test_data)
grouped_test_data['prob'] = np_prob
grouped_test_data['imp_sent_num'] = np.argmax(attention_scores,1)

grouped_test_data_reduced = grouped_test_data[np_prob>0.98]
grouped_test_data_reduced.index= range(len(grouped_test_data_reduced))

# %%
grouped_test_data.shape
# Out:
# (769, 5)

# %%
grouped_test_data
# Out:
#                               company1                           company2  \
# 0                        ALFA_(Mexico)                              Axtel
# 1                ARIAD_Pharmaceuticals      Takeda_Pharmaceutical_Company
# 2                                 AT&T                             Boeing
# 3                                 AT&T                       Boost_Mobile
# 4                                 AT&T              Bright_House_Networks
# 5                                 AT&T                              Buick
# 6                                 AT&T                    CBS_Corporation
# 7                                 AT&T                    CBS_Interactive
# 8                                 AT&T                       Calvin_Klein
# 9                                 AT&T                   Cricket_Wireless
# 10                                AT&T                   Deutsche_Telekom
# 11                                AT&T                     Disney_Channel
# 12                                AT&T                  Disneyland_Resort
# 13                                AT&T               Fullscreen_(company)
# 14                                AT&T                     General_Motors
# 15                                AT&T                                HBO
# 16                                AT&T                             Holden
# 17                                AT&T                           Instinet
# 18                                AT&T                  Johnson_&_Johnson
# 19                                AT&T                           LinkedIn
# 20                                AT&T                      Maker_Studios
# 21                                AT&T                      Mercedes-Benz
# 22                                AT&T                       NBCUniversal
# 23                                AT&T                             OnStar
# 24                                AT&T                             PayPal
# 25                                AT&T                             Pfizer
# 26                                AT&T                          Pizza_Hut
# 27                                AT&T                         Ram_Trucks
# 28                                AT&T                  Reynolds_American
# 29                                AT&T                         Sam's_Club
# ..                                 ...                                ...
# 739                            Walmart                BJ's_Wholesale_Club
# 740                            Walmart                             Boeing
# 741                            Walmart                                HBO
# 742                            Walmart                  Johnson_&_Johnson
# 743                            Walmart                           LinkedIn
# 744                            Walmart                           Old_Navy
# 745                            Walmart                             PayPal
# 746                            Walmart                       Safeway_Inc.
# 747                            Walmart                       Staples_Inc.
# 748                            Walmart                        T-Mobile_US
# 749                            Walmart                        Time_Warner
# 750                            Walmart  Walmart_de_México_y_Centroamérica
# 751                            Walmart                            YouTube
# 752  Walmart_de_México_y_Centroamérica                            Walmart
# 753      Walt_Disney_Parks_and_Resorts                          Lucasfilm
# 754      Walt_Disney_Parks_and_Resorts                      Marvel_Comics
# 755      Walt_Disney_Parks_and_Resorts                            YouTube
# 756                 Williams_Companies                  Chesapeake_Energy
# 757                             Yahoo!                               AT&T
# 758                             Yahoo!                            DirecTV
# 759                             Yahoo!                     General_Motors
# 760                             Yahoo!                           LinkedIn
# 761                             Yahoo!                       NBCUniversal
# 762                             Yahoo!                             PayPal
# 763                             Yahoo!                         Riot_Games
# 764                             Yahoo!                        T-Mobile_US
# 765                             Yahoo!                        Time_Warner
# 766                              Yukos                            Rosneft
# 767                      ZeniMax_Media                          Oculus_VR
# 768                              Ziggo                           Vodafone
#
#                                                snippet          prob  \
# 0    [ assets of its energy unit newpek, but that i...  2.156570e-04
# 1    [japan's company2 a ready for fresh acquisitio...  6.837936e-04
# 2    [  \n"immigrants or their children founded mor...  1.058349e-04
# 3    [ they're on different carriers:  company1 , v...  1.891391e-06
# 4    [o) purchase of time warner cable and  company...  1.733657e-03
# 5    [\nthe sponsorship from monster would add to h...  3.907995e-06
# 6    [ ( twx ) didn't have one either, until ceo je...  3.181220e-04
# 7    [\n"that's crazy," said the  company1  worker ...  9.958584e-01
# 8    [ they are industry professionals and have pro...  4.222701e-06
# 9    [ nevertheless, if you're interested, it'll wo...  4.575273e-05
# 10   [ telcos such as  company2 ,  company1 , and n...  2.612152e-05
# 11   [\nfor example, most shows on disney's abc, fr...  5.738035e-06
# 12   [\nthe 360-degree video ads already running in...  2.987433e-07
# 13   [\nas part of the online drive,  company1  is ...  9.986261e-01
# 14   ["\nthe ceeg represents a host of multinationa...  1.004726e-04
# 15   [ the end of net neutrality would also give ad...  1.169664e-04
# 16   [\nthe uk government and havas in the uk led t...  7.421801e-03
# 17   [ as with  company1 , that percentage was lowe...  2.123417e-06
# 18   [\nverizon and  company1  are the latest adver...  8.736483e-06
# 19   [ our customers demand it and our business dep...  5.412993e-05
# 20   [\nwalt disney ( dis ) acquired  company2 , wh...  2.929173e-04
# 21   [ 28, 2013 at  company1  stadium in arlington,...  2.208337e-01
# 22   [org,  company2 , and  company1  joined zendes...  6.054571e-05
# 23   [\ndata plans are offered to  company2  custom...  1.758766e-06
# 24   [,  company1 , capital one financial corp., ch...  7.594485e-07
# 25   [ however, concerns linger about the current a...  6.259943e-08
# 26   [ up at the top: mcdonald's,  company2 ,  comp...  1.866308e-07
# 27   [ so far, moth + flame has created about 15 br...  4.625923e-07
# 28   [ as well as the proposed bat and  company2  d...  3.077107e-02
# 29   [ target is offering an iphone 7 or iphone 7 p...  8.663375e-04
# ..                                                 ...           ...
# 739  [ sam's club is a membership warehouse chain o...  3.132169e-01
# 740  [  company2  , at&t , wells fargo , comcast , ...  1.270665e-05
# 741  [ "what we can be is the emotional connection ...  9.062584e-01
# 742  [ companies like johnson & johnson (nyse:  com...  4.834768e-06
# 743  [\nmajor corporations that have faced large da...  5.522758e-08
# 744  ["\nas a government agency, nasa has no intere...  1.138832e-05
# 745  [\nthe malware can produce fake login pages fo...  1.427370e-05
# 746  [ "she had to go find the latitude and longitu...  3.441711e-05
# 747  [\ngoogle chromecast: the 2nd gen version of g...  1.127153e-04
# 748  [  company1  includes other (earlier) iphone m...  8.391647e-07
# 749  [\nit's also worth more than well-known blue c...  5.778805e-05
# 750  [  company1  owned  company2  in mexico and th...  9.999893e-01
# 751  [ specifically,  company2  uploaded by nazi sy...  9.928966e-06
# 752  [\nmuch of the power produced by the wind turb...  5.237250e-04
# 753  [\nbesides just  company1 -branded properties,...  4.126698e-04
# 754  [\nthe one thing they both have in common? dc ...  1.293657e-03
# 755  [ you can preview the ride by watching a featu...  5.164521e-02
# 756  [  company2  gained 30 cents, or 4.9 percent, ...  2.869369e-06
# 757  [\nthe phone giant agreed in july to acquire t...  9.577690e-06
# 758  [  company2  plans a service for later this ye...  1.306571e-04
# 759  [ while, in the past, the agenda-setting confe...  1.453346e-08
# 760  [\nlast year ascend published "hidden in plain...  2.115311e-05
# 761  [\nalongside the investment from  company2 , p...  9.008032e-06
# 762  [\ncardiff-born sir michael is best known for ...  2.070560e-05
# 763  [\n"we first and foremost believe in making su...  4.218264e-05
# 764  [ company2 e's john legere says verizon compan...  7.859475e-05
# 765  [facebook, google, consolidation: what drove m...  3.168213e-03
# 766  [ he would eventually serve 10 years in prison...  7.004415e-03
# 767  [ also,  company2  was ordered to pay $500 mil...  9.867028e-01
# 768  [ liberty's  company1  is the largest cable tv...  1.467749e-02
#
#      imp_sent_num
# 0               0
# 1              18
# 2              17
# 3               6
# 4               0
# 5               0
# 6               2
# 7               0
# 8               0
# 9               2
# 10              3
# 11              0
# 12              0
# 13              0
# 14              5
# 15             18
# 16              0
# 17              1
# 18             22
# 19              1
# 20              0
# 21              3
# 22             16
# 23              0
# 24              2
# 25              1
# 26              0
# 27              0
# 28              0
# 29              0
# ..            ...
# 739             0
# 740             6
# 741             1
# 742             5
# 743             0
# 744             0
# 745             6
# 746            14
# 747            15
# 748             1
# 749             0
# 750            16
# 751            22
# 752            10
# 753             9
# 754             1
# 755             0
# 756             0
# 757             4
# 758             3
# 759             5
# 760            19
# 761             2
# 762             1
# 763            20
# 764             0
# 765             8
# 766             0
# 767            23
# 768             1
#
# [769 rows x 5 columns]

# %%
grouped_test_data.to_csv("../Radi/onto-test/vicky-test.csv")

# %%
top_results = grouped_test_data.sort_values('prob', ascending=False)[:80]
top_results.index = range(len(top_results))

# %%
top_results
# Out:
#                           company1                           company2  \
# 0              Danaher_Corporation                   Pall_Corporation
# 1                    Alibaba_Group                           AutoNavi
# 2               Berkshire_Hathaway                          NV_Energy
# 3                        UniCredit                    HypoVereinsbank
# 4               Oracle_Corporation                     MICROS_Systems
# 5                           Boeing                    Liquid_Robotics
# 6            RightNow_Technologies                 Oracle_Corporation
# 7                          Walmart  Walmart_de_México_y_Centroamérica
# 8                 Volkswagen_Group                          Chevrolet
# 9                           Boeing                             Pfizer
# 10                          Google                  Jaguar_Land_Rover
# 11                      Amazon.com                    British_Airways
# 12                      CareFusion                   Becton_Dickinson
# 13              Unocal_Corporation                Chevron_Corporation
# 14                        Facebook                       Ticketmaster
# 15                  Morgan_Stanley                            YouTube
# 16                         Twitter                              Dodge
# 17                    Marathon_Oil                         U.S._Steel
# 18                       Citigroup                             Boeing
# 19                       Citigroup                      Bank_Handlowy
# 20                         Comcast                 Paramount_Pictures
# 21                  Morgan_Stanley                               AT&T
# 22                         Twitter                            StubHub
# 23                        Facebook                              Optus
# 24            Disney_Vacation_Club            The_Walt_Disney_Company
# 25                         Tencent                                HBO
# 26                            AT&T               Fullscreen_(company)
# 27                Volkswagen_Group                        Lamborghini
# 28              Singapore_Airlines                             Boeing
# 29                       Microsoft                        SmartThings
# ..                             ...                                ...
# 50                      Apple_Inc.                  Disneyland_Resort
# 51                   Camping_World                    Gander_Mountain
# 52              Berkshire_Hathaway                     General_Motors
# 53                         Walmart                                HBO
# 54                       Lufthansa                   Iberia_(airline)
# 55                         Textron                             Boeing
# 56                         EnerNOC                               Enel
# 57                          PayPal                             Boeing
# 58                         Twitter                        DoubleClick
# 59                          Boeing                  Standard_&_Poor's
# 60                American_Capital                    Ares_Management
# 61             Centene_Corporation                         Health_Net
# 62                  Morgan_Stanley                           LinkedIn
# 63              Ford_Motor_Company                                HBO
# 64                      ExxonMobil                  Standard_&_Poor's
# 65                          Google                               Jeep
# 66                         Twitter                              Optus
# 67              Oracle_Corporation                           LinkedIn
# 68  Teva_Pharmaceutical_Industries                           Cephalon
# 69                       Nest_Labs                     Alexa_Internet
# 70                General_Electric                  Standard_&_Poor's
# 71                         Tencent                           LinkedIn
# 72                         Rosneft                              Yukos
# 73                           Axtel                      ALFA_(Mexico)
# 74        British_American_Tobacco                  Reynolds_American
# 75                Pall_Corporation                Danaher_Corporation
# 76                          Google                            Dropcam
# 77                            HSBC                               Audi
# 78   The_Walt_Disney_Company_Italy            The_Walt_Disney_Company
# 79                            Audi                         Volvo_Cars
#
#                                               snippet      prob  imp_sent_num
# 0   [  company2  is being acquired by  company1  (...  0.999997             0
# 1   [ but when users of the app attempt to use its...  0.999997             2
# 2   [ buffett and musk have also competed in other...  0.999995             3
# 3   [ commerzbank has around 8 percent of the germ...  0.999995             2
# 4   [  company1  acquired micros in 2014, when it ...  0.999993             6
# 5   [  company1  acquired undersea drone maker  co...  0.999993             0
# 6   [ he sold  company1  to  company2  in 2012 for...  0.999990             0
# 7   [  company1  owned  company2  in mexico and th...  0.999989            16
# 8   [ announced it would scrap a $1 billion invest...  0.999987             2
# 9   [ a group of major exporters, including  compa...  0.999982             0
# 10  [ \n company2  will put a fleet of 100 autonom...  0.999969             8
# 11  [com inc ( company1 .o) is negotiating to leas...  0.999967             0
# 12  [\nacquisition of  company1  corp. he oversaw ...  0.999916             2
# 13  [ and  company1  into  company2 . they were pu...  0.999914             0
# 14  [  company1  also works with  company2  and ev...  0.999747             1
# 15  [65 billion acquisition of  company2  in 2006 ...  0.999707             0
# 16  [\n company2  and his cofounders collaborated ...  0.999692             0
# 17  [ in 1982, in a diversification bid, the compa...  0.999557             0
# 18  [ it is very hard to catch up all of it at one...  0.999418             0
# 19  [\n"it's hard to precisely assess the impact o...  0.999415             0
# 20  [b )  company2  and  company1  ( cmcsa ) unive...  0.999397             3
# 21  [\n"we intend to offer customers a quality pay...  0.999194             1
# 22  [ the most inexpensive seat as of 5 pm et was ...  0.999112             2
# 23  [ visit  company1  pages of telstra or  compan...  0.999040             0
# 24  [ the wages will be paid to 16,339 employees a...  0.998997             0
# 25  [\nthe company's netflix-style  company1  vide...  0.998763             4
# 26  [\nas part of the online drive,  company1  is ...  0.998626             0
# 27  [ (both  company2  and porsche are part of the...  0.998539            13
# 28  ["\nseparately,  company2  also rolled out its...  0.998194            17
# 29  [ i was able to voice control my hue lights an...  0.997924             2
# ..                                                ...       ...           ...
# 50  [data sheet—disney and company1 e head for con...  0.926767             0
# 51  [\nmarcus lemonis, star of the cnbc show "the ...  0.920981             6
# 52  [buffett doesn't see a company2 m $8 billion b...  0.920820             2
# 53  [ "what we can be is the emotional connection ...  0.906258             1
# 54  [\nlike its two major competitors, internation...  0.845945             0
# 55  [\nthe osprey is built by  company2  and  comp...  0.838271            11
# 56  [\n company1 , an  company2  company, first es...  0.826915             0
# 57  [ among them: nasa recently selected aviation ...  0.821209             0
# 58  [ it has also included  company1  in its  comp...  0.808391             3
# 59  [  company1 ?s 11 percent gain this year throu...  0.803489             0
# 60  [\n company2  agreed to buy the majority of pu...  0.778638             4
# 61  [ for $35 billion earlier this month, a day af...  0.777406            18
# 62  [\nmicrosoft's financial adviser was  company1...  0.765107             1
# 63  [ or, try  company1 's final narrative or the ...  0.738939             0
# 64  [ \n company1  was demoted from the top credit...  0.716558             1
# 65  [\n"this is a violation of some very basic and...  0.657260             0
# 66  [\n company2  has yet to make any official com...  0.626534             1
# 67  [2 billion bid for  company2 , announced in ju...  0.590925             2
# 68  [ antitrust regulators have settled a long-run...  0.589414             0
# 69  [ for instance, siri can only control homekit ...  0.577705             5
# 70  [ stocks advance before earnings reports as co...  0.576928             7
# 71  [ in fact, drawing a line on "who's chinese an...  0.555480             2
# 72  [\nin russia, exxonmobil's partner has been th...  0.515294             1
# 73  [ assets of its energy unit newpek, but that i...  0.510736             0
# 74  [ the first —  company1 's agreement to purcha...  0.495057             8
# 75  [  company1  is being acquired by  company2  (...  0.469930             0
# 76  [\nthe idea here is to provide a 14,000 square...  0.468871             2
# 77  [ the bbc, l'oréal,  company1 , royal bank of ...  0.445760             1
# 78  [ the_walt_ company2 _company_italy has not ye...  0.432597             0
# 79  [android cars at google i/o 2017: company1 i a...  0.414373             6
#
# [80 rows x 5 columns]

# %%
top_results.iloc[15]['company1'], top_results.iloc[15]['company2']
# Out:
# ('Morgan_Stanley', 'YouTube')

# %%
def return_actual_parent (predicted_subsidiary_name):
    try:
        return (list(train_data[(train_data['company2']==predicted_subsidiary_name)&(train_data['is_parent'])==True]['company1'])[0])
    except:
        return 'No_parent'

# %%
count = 0
identified_pairs = []
top_results_fp_removed = []
for index, row in top_results.iterrows():
    actual_parent_name = return_actual_parent(row['company2'])
    if actual_parent_name=='No_parent' or actual_parent_name==row['company1']:
        if [row['company2'],row['company1']] not in identified_pairs:
            identified_pairs.append([row['company1'], row['company2']])
            top_results_fp_removed.append(row)

# %%
top_results_fp_removed = pd.DataFrame(top_results_fp_removed)
top_results_fp_removed.index = range(len(top_results_fp_removed))

# %%
top_results_fp_removed
# Out:
#                            company1                           company2  \
# 0               Danaher_Corporation                   Pall_Corporation
# 1                     Alibaba_Group                           AutoNavi
# 2                Berkshire_Hathaway                          NV_Energy
# 3                         UniCredit                    HypoVereinsbank
# 4                Oracle_Corporation                     MICROS_Systems
# 5                            Boeing                    Liquid_Robotics
# 6             RightNow_Technologies                 Oracle_Corporation
# 7                           Walmart  Walmart_de_México_y_Centroamérica
# 8                            Boeing                             Pfizer
# 9                        CareFusion                   Becton_Dickinson
# 10               Unocal_Corporation                Chevron_Corporation
# 11                     Marathon_Oil                         U.S._Steel
# 12                        Citigroup                             Boeing
# 13                        Citigroup                      Bank_Handlowy
# 14                          Comcast                 Paramount_Pictures
# 15                   Morgan_Stanley                               AT&T
# 16             Disney_Vacation_Club            The_Walt_Disney_Company
# 17                          Tencent                                HBO
# 18                             AT&T               Fullscreen_(company)
# 19               Singapore_Airlines                             Boeing
# 20                            Alere                Abbott_Laboratories
# 21                             AT&T                    CBS_Interactive
# 22                Chesapeake_Energy                 Williams_Companies
# 23                   Ingersoll_Rand                              Trane
# 24  Simmons_&_Company_International                      Piper_Jaffray
# 25          The_Walt_Disney_Company                     General_Motors
# 26          The_Walt_Disney_Company      The_Walt_Disney_Company_Italy
# 27                       Apple_Inc.                 Paramount_Pictures
# 28                       Amazon.com                  Disneyland_Resort
# 29                       Medivation                           Allergan
# 30                       Apple_Inc.                           Allergan
# 31                       Apple_Inc.                  Disneyland_Resort
# 32                    Camping_World                    Gander_Mountain
# 33               Berkshire_Hathaway                     General_Motors
# 34                          Walmart                                HBO
# 35                          Textron                             Boeing
# 36                          EnerNOC                               Enel
# 37                           PayPal                             Boeing
# 38                           Boeing                  Standard_&_Poor's
# 39                 American_Capital                    Ares_Management
# 40              Centene_Corporation                         Health_Net
# 41               Ford_Motor_Company                                HBO
# 42                       ExxonMobil                  Standard_&_Poor's
# 43   Teva_Pharmaceutical_Industries                           Cephalon
# 44                 General_Electric                  Standard_&_Poor's
# 45                          Rosneft                              Yukos
# 46                            Axtel                      ALFA_(Mexico)
# 47         British_American_Tobacco                  Reynolds_American
#
#                                               snippet      prob  imp_sent_num
# 0   [  company2  is being acquired by  company1  (...  0.999997             0
# 1   [ but when users of the app attempt to use its...  0.999997             2
# 2   [ buffett and musk have also competed in other...  0.999995             3
# 3   [ commerzbank has around 8 percent of the germ...  0.999995             2
# 4   [  company1  acquired micros in 2014, when it ...  0.999993             6
# 5   [  company1  acquired undersea drone maker  co...  0.999993             0
# 6   [ he sold  company1  to  company2  in 2012 for...  0.999990             0
# 7   [  company1  owned  company2  in mexico and th...  0.999989            16
# 8   [ a group of major exporters, including  compa...  0.999982             0
# 9   [\nacquisition of  company1  corp. he oversaw ...  0.999916             2
# 10  [ and  company1  into  company2 . they were pu...  0.999914             0
# 11  [ in 1982, in a diversification bid, the compa...  0.999557             0
# 12  [ it is very hard to catch up all of it at one...  0.999418             0
# 13  [\n"it's hard to precisely assess the impact o...  0.999415             0
# 14  [b )  company2  and  company1  ( cmcsa ) unive...  0.999397             3
# 15  [\n"we intend to offer customers a quality pay...  0.999194             1
# 16  [ the wages will be paid to 16,339 employees a...  0.998997             0
# 17  [\nthe company's netflix-style  company1  vide...  0.998763             4
# 18  [\nas part of the online drive,  company1  is ...  0.998626             0
# 19  ["\nseparately,  company2  also rolled out its...  0.998194            17
# 20  [8 billion deal for  company1  inc (alr.n).\n ...  0.997625             8
# 21  [\n"that's crazy," said the  company1  worker ...  0.995858             0
# 22  ["\nsecond, acquiring  company2  would raise e...  0.995369             7
# 23  [ it is engaged in the design, manufacture, sa...  0.993933             1
# 24  [\nanalysts at  company1  & co, energy special...  0.990255             0
# 25  [\nother panel members include  company2  co. ...  0.989946             2
# 26  [ the_walt_ company1 _company_italy has not ye...  0.989758             0
# 27  [\n company1  execs have met with  company2 , ...  0.983762            23
# 28  [\nwalt disney —disney will be adding star war...  0.959145             0
# 29  [\nnew york-based pfizer has been looking for ...  0.947070             0
# 30  [ \n company1 ,  company2  and nxp semiconduct...  0.944525             2
# 31  [data sheet—disney and company1 e head for con...  0.926767             0
# 32  [\nmarcus lemonis, star of the cnbc show "the ...  0.920981             6
# 33  [buffett doesn't see a company2 m $8 billion b...  0.920820             2
# 34  [ "what we can be is the emotional connection ...  0.906258             1
# 35  [\nthe osprey is built by  company2  and  comp...  0.838271            11
# 36  [\n company1 , an  company2  company, first es...  0.826915             0
# 37  [ among them: nasa recently selected aviation ...  0.821209             0
# 38  [  company1 ?s 11 percent gain this year throu...  0.803489             0
# 39  [\n company2  agreed to buy the majority of pu...  0.778638             4
# 40  [ for $35 billion earlier this month, a day af...  0.777406            18
# 41  [ or, try  company1 's final narrative or the ...  0.738939             0
# 42  [ \n company1  was demoted from the top credit...  0.716558             1
# 43  [ antitrust regulators have settled a long-run...  0.589414             0
# 44  [ stocks advance before earnings reports as co...  0.576928             7
# 45  [\nin russia, exxonmobil's partner has been th...  0.515294             1
# 46  [ assets of its energy unit newpek, but that i...  0.510736             0
# 47  [ the first —  company1 's agreement to purcha...  0.495057             8

# %%
print(top_results_fp_removed[['company1','company2']])
# Out:
#                            company1                           company2
# 0               Danaher_Corporation                   Pall_Corporation
# 1                     Alibaba_Group                           AutoNavi
# 2                Berkshire_Hathaway                          NV_Energy
# 3                         UniCredit                    HypoVereinsbank
# 4                Oracle_Corporation                     MICROS_Systems
# 5                            Boeing                    Liquid_Robotics
# 6             RightNow_Technologies                 Oracle_Corporation
# 7                           Walmart  Walmart_de_México_y_Centroamérica
# 8                            Boeing                             Pfizer
# 9                        CareFusion                   Becton_Dickinson
# 10               Unocal_Corporation                Chevron_Corporation
# 11                     Marathon_Oil                         U.S._Steel
# 12                        Citigroup                             Boeing
# 13                        Citigroup                      Bank_Handlowy
# 14                          Comcast                 Paramount_Pictures
# 15                   Morgan_Stanley                               AT&T
# 16             Disney_Vacation_Club            The_Walt_Disney_Company
# 17                          Tencent                                HBO
# 18                             AT&T               Fullscreen_(company)
# 19               Singapore_Airlines                             Boeing
# 20                            Alere                Abbott_Laboratories
# 21                             AT&T                    CBS_Interactive
# 22                Chesapeake_Energy                 Williams_Companies
# 23                   Ingersoll_Rand                              Trane
# 24  Simmons_&_Company_International                      Piper_Jaffray
# 25          The_Walt_Disney_Company                     General_Motors
# 26          The_Walt_Disney_Company      The_Walt_Disney_Company_Italy
# 27                       Apple_Inc.                 Paramount_Pictures
# 28                       Amazon.com                  Disneyland_Resort
# 29                       Medivation                           Allergan
# 30                       Apple_Inc.                           Allergan
# 31                       Apple_Inc.                  Disneyland_Resort
# 32                    Camping_World                    Gander_Mountain
# 33               Berkshire_Hathaway                     General_Motors
# 34                          Walmart                                HBO
# 35                          Textron                             Boeing
# 36                          EnerNOC                               Enel
# 37                           PayPal                             Boeing
# 38                           Boeing                  Standard_&_Poor's
# 39                 American_Capital                    Ares_Management
# 40              Centene_Corporation                         Health_Net
# 41               Ford_Motor_Company                                HBO
# 42                       ExxonMobil                  Standard_&_Poor's
# 43   Teva_Pharmaceutical_Industries                           Cephalon
# 44                 General_Electric                  Standard_&_Poor's
# 45                          Rosneft                              Yukos
# 46                            Axtel                      ALFA_(Mexico)
# 47         British_American_Tobacco                  Reynolds_American

# %%
text_num = 35

# %%
print('Predicted parent:',top_results_fp_removed['company1'][text_num])
print('Predicted subsidiary:',top_results_fp_removed['company2'][text_num])
# Out:
# Predicted parent: Textron
# Predicted subsidiary: Boeing

# %%
print('Important Sentence')
print(top_results_fp_removed['snippet'][text_num][top_results_fp_removed['imp_sent_num'][text_num]])
# Out:
# Important Sentence
#  instead, uber is building the software to manage networks in the sky of flying taxis, while relying on a stable of manufacturers, including aurora flight sciences, which was acquired by  company2  last month.
# uber has also signed up embraer, mooney, bell helicopter - a unit of  company1  -, and pipistrel aircraft to build new vertical takeoff and landing aircraft. ###end###

# %%
print('Input snippets:')
for i, snippet in enumerate(top_results_fp_removed['snippet'][text_num]):
    print(i+1, snippet, end='\n\n')
# Out:
# Input snippets:
# 1
# the osprey is built by  company2  and  company1 's bell helicopter division. ###end###
#
# 2
# built by  company2  and bell, a unit of  company1 , the osprey program was nearly scrapped after a history of mechanical failures and two test crashes that killed 23 marines in 2000. ###end###
#
# 3
# mitch snyder, president & ceo, bell helicopter,  company1
# kevin mcallister, president and chief executive officer,  company2 , the  company2  co. ###end###
#
# 4 -india business council along with about 25 defense firms, including giants  company2 , lockheed martin and  company1 , defense news reports. ###end###
#
# 5 -india business council along with about 25 defense firms, including giants  company2 , lockheed martin and  company1 , defense news reports.  company2  will get some extra attention when parrikar stops by a  company2  facility near philadelphia that is churning out ch-47f chinook heavy-lift helicopters that india purchased last year as part of a $3. ###end###
#
# 6
# the osprey, built by  company2  co ( ba.n ) and  company1 's ( txt. ###end###
#
# 7
# the osprey, built by  company2  co and  company1 's bell helicopter unit, is designed to take off like a helicopter and rotate its propellers to fly like a plane. ###end###
#
# 8
# analysts on thursday said the potential for a big tax bill means sikorsky will more likely be spun off into a standalone company than sold outright to potential buyers such as  company2  co (ba.n),  company1  (txt. ###end###
#
# 9
# the board met last week to discuss its options after receiving a number of offers for sikorsky, including one that would combine the company with the bell helicopter unit of  company1 , reuters reported last week.
# lockheed martin corp and  company2  co have also expressed interest in a potential deal. ###end###
#
# 10  trade buyers such as  company2  or even a combination with the bell unit of  company1  are viewed as less likely. ###end###
#
# 11
# access investor kit for  company2
# access investor kit for lockheed martin corp.
# access investor kit for  company1
# access investor kit for united technologies corp. ###end###
#
# 12  instead, uber is building the software to manage networks in the sky of flying taxis, while relying on a stable of manufacturers, including aurora flight sciences, which was acquired by  company2  last month.
# uber has also signed up embraer, mooney, bell helicopter - a unit of  company1  -, and pipistrel aircraft to build new vertical takeoff and landing aircraft. ###end###
#
# 13
#  company1  then reached out private equity firms for help to make a cash offer, the sources said.
#  company2  co (ba. ###end###
#
# 14
# representatives for utc, lockheed,  company1 ,  company2  and airbus declined comment. ###end###
#
# 15
# representatives for utc, lockheed,  company1 ,  company2  and airbus declined comment.
# analysts have focused on  company1  as the likeliest buyer, given its interest in beefing up its existing bell helicopter business. ###end###
#
# 16
# the development of the osprey — built by  company2  co and  company1 's bell helicopter unit — was nearly cancelled after the deaths of 23 marines during flight testing in 2000, but its speed and range have made it very popular in recent years. ###end###
#
# 17  drone makers general atomics,  company2 , northrop grumman,  company1  and lockheed martin. ###end###
