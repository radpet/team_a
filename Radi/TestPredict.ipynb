# %%
import pandas as pd

# %%
result = pd.read_csv("./onto-test/bi_lstm.csv")

# %%
result[:30]
# Out:
#                          company1               company2  is_parent  \
# 0                       UniCredit        HypoVereinsbank   0.999999
# 1                          Google                Dropcam   0.999999
# 2                Volkswagen_Group            Lamborghini   0.999999
# 3                          Pfizer               Allergan   0.999999
# 4                            AT&T            Time_Warner   0.999997
# 5   Takeda_Pharmaceutical_Company  ARIAD_Pharmaceuticals   0.999997
# 6        British_American_Tobacco      Reynolds_American   0.999997
# 7                            AT&T            Time_Warner   0.999996
# 8                 Bank_of_America        Jefferies_Group   0.999996
# 9                          Google           Warner_Bros.   0.999995
# 10                          Tesco          Ben_&_Jerry's   0.999995
# 11                     Amazon.com           Warner_Bros.   0.999994
# 12               Volkswagen_Group            Lamborghini   0.999993
# ...
