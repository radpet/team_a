# %%
import pandas as pd

# %%
dataset = pd.read_csv("../data/train.csv")

# %%
dataset[:20]
# Out:
#                    company1                company2  is_parent  \
# 0        Sprint_Corporation  Verizon_Communications      False
# 1        Sprint_Corporation  Verizon_Communications      False
# 2        Sprint_Corporation  Verizon_Communications      False
# 3            Alexa_Internet              Amazon.com      False
# 4            Alexa_Internet              Amazon.com      False
# 5            Alexa_Internet              Amazon.com      False
# 6                 Lufthansa         British_Airways      False
# 7                      Asda                 Walmart      False
# 8   The_Walt_Disney_Company           Marvel_Comics       True
# 9                   Comcast  Verizon_Communications      False
# 10                  Comcast  Verizon_Communications      False
# 11                  Comcast  Verizon_Communications      False
# 12                      AOL  Verizon_Communications      False
# 13                      AOL  Verizon_Communications      False
# ...

# %%
dataset["is_parent"].value_counts()
# Out:
# False    62881
# True     26571
# Name: is_parent, dtype: int64

# %%
dataset.describe()
# Out:
#        company1 company2 is_parent  \
# count     89452    89452     89452
# unique      440      447         2
# top      Google  YouTube     False
# freq       7348    13001     62881
#
#                                                   snippet
# count                                               89452
# unique                                              52175
# top     \nFollow Business Insider Australia on Faceboo...
# freq                                                  271

# %%
dataset["company1"].value_counts()
# Out:
# Google                          7348
# YouTube                         5347
# Twitter                         4836
# Amazon.com                      4596
# Facebook                        3604
# Verizon_Communications          3236
# Alexa_Internet                  2977
# Sprint_Corporation              2763
# Apple_Inc.                      2694
# The_Walt_Disney_Company         2518
# Ford_Motor_Company              2353
# Yahoo!                          1857
# Microsoft                       1604
# Comcast                         1428
# General_Motors                  1211
# Samsung                         1081
# AT&T                            1081
# T-Mobile                         913
# Chrysler                         906
# Fiat_Chrysler_Automobiles        876
# LinkedIn                         854
# DirecTV                          786
# Time_Warner                      772
# Audi                             768
# Lucasfilm                        601
# ...

# %%
dataset["company2"].value_counts()
# Out:
# YouTube                          13001
# Google                            6079
# AT&T                              5074
# General_Motors                    4655
# Verizon_Communications            4306
# Alexa_Internet                    3983
# Amazon.com                        2977
# LinkedIn                          2387
# T-Mobile_US                       2015
# Time_Warner                       1421
# The_Walt_Disney_Company           1409
# Chevrolet                         1287
# DirecTV                           1185
# PayPal                            1035
# AOL                               1028
# Microsoft                          915
# HBO                                785
# Jeep                               625
# Audi                               614
# Porsche                            599
# NBCUniversal                       572
# Lucasfilm                          556
# International_Airlines_Group       555
# Mercedes-Benz                      524
# ...
